# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
DATA_PATH = 'dataset'
RETRIEVE_NUM = 25

MODEL_OUTPUT_PATH = 'model/'

test = pd.read_csv(f"{DATA_PATH}/test.csv")
misconception_mapping = pd.read_csv(f"{DATA_PATH}/misconception_mapping.csv")

# %%
common_col = [
    "QuestionId",
    "ConstructName",
    "SubjectName",
    "QuestionText",
    "CorrectAnswer",
]

test_long = (
    test[common_col + [f"Answer{alpha}Text" for alpha in ["A", "B", "C", "D"]]]
    .melt(
        id_vars=common_col,
        value_vars=[f"Answer{alpha}Text" for alpha in ["A", "B", "C", "D"]],
        var_name="AnswerType",
        value_name="AnswerText"
    )
)
test_long["AllText"] = test_long["ConstructName"] + " " + test_long["SubjectName"] + " " + test_long["QuestionText"] + " " + test_long["AnswerText"]
test_long["AnswerAlphabet"] = test_long["AnswerType"].str.extract(r"Answer([A-D])Text$")
test_long["QuestionId_Answer"] = test_long["QuestionId"].astype(str) + "_" + test_long["AnswerAlphabet"]

# %%
test_long
# Out:
#     QuestionId                                      ConstructName  \
# 0         1869  Use the order of operations to carry out calcu...
# 1         1870  Simplify an algebraic fraction by factorising ...
# 2         1871            Calculate the range from a list of data
# 3         1869  Use the order of operations to carry out calcu...
# 4         1870  Simplify an algebraic fraction by factorising ...
# 5         1871            Calculate the range from a list of data
# 6         1869  Use the order of operations to carry out calcu...
# 7         1870  Simplify an algebraic fraction by factorising ...
# 8         1871            Calculate the range from a list of data
# 9         1869  Use the order of operations to carry out calcu...
# 10        1870  Simplify an algebraic fraction by factorising ...
# 11        1871            Calculate the range from a list of data
#
#                                           SubjectName  \
# 0                                              BIDMAS
# 1                     Simplifying Algebraic Fractions
# 2   Range and Interquartile Range from a List of Data
# 3                                              BIDMAS
# 4                     Simplifying Algebraic Fractions
# 5   Range and Interquartile Range from a List of Data
# 6                                              BIDMAS
# 7                     Simplifying Algebraic Fractions
# 8   Range and Interquartile Range from a List of Data
# 9                                              BIDMAS
# 10                    Simplifying Algebraic Fractions
# 11  Range and Interquartile Range from a List of Data
#
#                                          QuestionText CorrectAnswer  \
# 0   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...             A
# 1   Simplify the following, if possible: \( \frac{...             D
# 2   Tom and Katie are discussing the \( 5 \) plant...             B
# 3   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...             A
# 4   Simplify the following, if possible: \( \frac{...             D
# 5   Tom and Katie are discussing the \( 5 \) plant...             B
# 6   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...             A
# 7   Simplify the following, if possible: \( \frac{...             D
# 8   Tom and Katie are discussing the \( 5 \) plant...             B
# 9   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...             A
# 10  Simplify the following, if possible: \( \frac{...             D
# 11  Tom and Katie are discussing the \( 5 \) plant...             B
#
#      AnswerType              AnswerText  \
# 0   AnswerAText   \( 3 \times(2+4)-5 \)
# 1   AnswerAText               \( m+1 \)
# 2   AnswerAText               Only\nTom
# 3   AnswerBText  \( 3 \times 2+(4-5) \)
# 4   AnswerBText               \( m+2 \)
# 5   AnswerBText             Only\nKatie
# 6   AnswerCText   \( 3 \times(2+4-5) \)
# 7   AnswerCText               \( m-1 \)
# 8   AnswerCText      Both Tom and Katie
# 9   AnswerDText  Does not need brackets
# 10  AnswerDText       Does not simplify
# 11  AnswerDText      Neither is correct
#
#                                               AllText AnswerAlphabet  \
# 0   Use the order of operations to carry out calcu...              A
# 1   Simplify an algebraic fraction by factorising ...              A
# 2   Calculate the range from a list of data Range ...              A
# 3   Use the order of operations to carry out calcu...              B
# 4   Simplify an algebraic fraction by factorising ...              B
# 5   Calculate the range from a list of data Range ...              B
# 6   Use the order of operations to carry out calcu...              C
# 7   Simplify an algebraic fraction by factorising ...              C
# 8   Calculate the range from a list of data Range ...              C
# 9   Use the order of operations to carry out calcu...              D
# 10  Simplify an algebraic fraction by factorising ...              D
# 11  Calculate the range from a list of data Range ...              D
#
#    QuestionId_Answer
# 0             1869_A
# 1             1870_A
# 2             1871_A
# 3             1869_B
# 4             1870_B
# 5             1871_B
# 6             1869_C
# 7             1870_C
# 8             1871_C
# 9             1869_D
# 10            1870_D
# 11            1871_D

# %%
model = SentenceTransformer(MODEL_OUTPUT_PATH)

test_long_vec = model.encode(
    test_long["AllText"].to_list(), normalize_embeddings=True
)
misconception_mapping_vec = model.encode(
    misconception_mapping["MisconceptionName"].to_list(), normalize_embeddings=True
)
print(test_long_vec.shape)
print(misconception_mapping_vec.shape)
# Out:
# (12, 1024)
# (2587, 1024)

# %%
test_cos_sim_arr = cosine_similarity(test_long_vec, misconception_mapping_vec)
test_sorted_indices = np.argsort(-test_cos_sim_arr, axis=1)[:, :RETRIEVE_NUM]

# %%
test_long["MisconceptionId"] = [" ".join(map(str, indices)) for indices in test_sorted_indices]
test_long["MisconceptionText"] = ["\n".join(misconception_mapping.iloc[indices]["MisconceptionName"].values) for indices in test_sorted_indices]

# Filter where CorrectAnswer != AnswerAlphabet
filtered_test_long = test_long[test_long["CorrectAnswer"] != test_long["AnswerAlphabet"]]

# Select relevant columns and sort by QuestionId_Answer
submission = filtered_test_long[["QuestionId_Answer", "MisconceptionId", "MisconceptionText"]].sort_values(by="QuestionId_Answer")

# %%
submission
# Out:
#    QuestionId_Answer MisconceptionId  \
# 3             1869_B            1507
# 6             1869_C            1507
# 9             1869_D            1507
# 1             1870_A            2549
# 4             1870_B            2549
# 7             1870_C            2549
# 2             1871_A            1287
# 8             1871_C            1287
# 11            1871_D            1287
#
#                                     MisconceptionText
# 3   Carries out operations from left to right rega...
# 6   Carries out operations from left to right rega...
# 9   Carries out operations from left to right rega...
# 1   Believes only the first term needs to be divid...
# 4   Believes only the first term needs to be divid...
# 7   Believes only the first term needs to be divid...
# 2   Believes if you changed all values by the same...
# 8   Believes if you changed all values by the same...
# 11  Believes if you changed all values by the same...
