# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /home/t/tienkhoa/miniconda3/envs/cs5242/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
DATA_PATH = 'dataset'
RETRIEVE_NUM = 25

MODEL_OUTPUT_PATH = 'model/'

test = pd.read_csv(f"{DATA_PATH}/test.csv")
misconception_mapping = pd.read_csv(f"{DATA_PATH}/misconception_mapping.csv")

# %%
common_col = [
    "QuestionId",
    "ConstructName",
    "SubjectName",
    "QuestionText",
    "CorrectAnswer",
]

test_long = (
    test[common_col + [f"Answer{alpha}Text" for alpha in ["A", "B", "C", "D"]]]
    .melt(
        id_vars=common_col,
        value_vars=[f"Answer{alpha}Text" for alpha in ["A", "B", "C", "D"]],
        var_name="AnswerType",
        value_name="AnswerText"
    )
)
test_long["AllText"] = test_long["ConstructName"] + " " + test_long["SubjectName"] + " " + test_long["QuestionText"] + " " + test_long["AnswerText"]
test_long["AnswerAlphabet"] = test_long["AnswerType"].str.extract(r"Answer([A-D])Text$")
test_long["QuestionId_Answer"] = test_long["QuestionId"].astype(str) + "_" + test_long["AnswerAlphabet"]

# %%
test_long
# Out:
#      QuestionId                                      ConstructName  \
# 0           794  Know that the probabilities of exhaustive even...
# 1           248         Recognise a quadratic graph from its shape
# 2          1376  Identify percentages of a shape where the perc...
# 3           473  Recognise the place value of each digit in int...
# 4           695  Use the order of operations to carry out calcu...
# ..          ...                                                ...
# 743         207  Simplify algebraic expressions to maintain equ...
# 744        1341  Label angles using correct 3-letter notation (...
# 745         144     Continue a sequence involving triangle numbers
# 746        1563  Calculate the midpoint between two coordinates...
# 747         346                        Convert ratios to fractions
#
#                            SubjectName  \
# 0         Probability of Single Events
# 1              Quadratic Graphs-Others
# 2               Fractions of an Amount
# 3                          Place Value
# 4                               BIDMAS
# ..                                 ...
# 743          Expanding Single Brackets
# 744       Types, Naming and Estimating
# 745                    Other Sequences
# 746  Midpoint Between Two Co-ordinates
# 747                     Writing Ratios
#
#                                           QuestionText CorrectAnswer  \
# 0    A bag contains some strawberry sweets, some or...             D
# 1    Which of the following is an example of a quad...             D
# 2    What percentage of this shape is shaded? ![A b...             B
# 3    What is the value of the \( 3 \) in the number...             D
# 4                          \( 18 \div 2+2 \times 2= \)             B
# ..                                                 ...           ...
# 743  \(\nx(3 x-5)+6(2 x-3) \equiv P x^{2}+Q x+R\n\)...             B
# 744  Which of the following correctly describes the...             D
# 745  If you add together consecutive triangle numbe...             A
# 746  Cara is trying to work out the midpoint of the...             C
# 747  Kate and Isaac share some yoghurt in the ratio...             D
#
#       AnswerType                                         AnswerText  \
# 0    AnswerAText                                  \( \frac{1}{3} \)
# 1    AnswerAText  ![A graph showing a straight line from top lef...
# 2    AnswerAText                                        \( 30 \% \)
# 3    AnswerAText                                        \( 30000 \)
# 4    AnswerAText                                            \( 3 \)
# ..           ...                                                ...
# 743  AnswerDText                                           \( -3 \)
# 744  AnswerDText                                                FGH
# 745  AnswerDText                                 a Fibonacci number
# 746  AnswerDText                                          \( 3.5 \)
# 747  AnswerDText                                  \( \frac{2}{7} \)
#
#                                                AllText AnswerAlphabet  \
# 0    Know that the probabilities of exhaustive even...              A
# 1    Recognise a quadratic graph from its shape Qua...              A
# 2    Identify percentages of a shape where the perc...              A
# 3    Recognise the place value of each digit in int...              A
# 4    Use the order of operations to carry out calcu...              A
# ..                                                 ...            ...
# 743  Simplify algebraic expressions to maintain equ...              D
# 744  Label angles using correct 3-letter notation (...              D
# 745  Continue a sequence involving triangle numbers...              D
# 746  Calculate the midpoint between two coordinates...              D
# 747  Convert ratios to fractions Writing Ratios Kat...              D
#
#     QuestionId_Answer
# 0               794_A
# 1               248_A
# 2              1376_A
# 3               473_A
# 4               695_A
# ..                ...
# 743             207_D
# 744            1341_D
# 745             144_D
# 746            1563_D
# 747             346_D
#
# [748 rows x 10 columns]

# %%
model = SentenceTransformer(MODEL_OUTPUT_PATH)

test_long_vec = model.encode(
    test_long["AllText"].to_list(), normalize_embeddings=True
)
misconception_mapping_vec = model.encode(
    misconception_mapping["MisconceptionName"].to_list(), normalize_embeddings=True
)
print(test_long_vec.shape)
print(misconception_mapping_vec.shape)
# Out:
# (748, 1024)
# (2587, 1024)

# %%
test_cos_sim_arr = cosine_similarity(test_long_vec, misconception_mapping_vec)
test_sorted_indices = np.argsort(-test_cos_sim_arr, axis=1)[:, :RETRIEVE_NUM]

# %%
test_long["MisconceptionId"] = [" ".join(map(str, indices)) for indices in test_sorted_indices]
test_long["MisconceptionText"] = ["\n".join(misconception_mapping.iloc[indices]["MisconceptionName"].values) for indices in test_sorted_indices]

# Filter where CorrectAnswer != AnswerAlphabet
filtered_test_long = test_long[test_long["CorrectAnswer"] != test_long["AnswerAlphabet"]]

# Select relevant columns and sort by QuestionId_Answer
submission = filtered_test_long[["QuestionId_Answer", "MisconceptionId"]].sort_values(by="QuestionId_Answer")
submission.to_csv("submission.csv", index=False)

# %%
submission
# Out:
#     QuestionId_Answer                                    MisconceptionId
# 5              1001_A  2330 1379 1988 1605 1675 2515 1272 1529 1248 8...
# 379            1001_C  2330 1379 1988 1605 1675 2515 1248 1272 1529 2...
# 566            1001_D  2330 1379 1988 1605 2515 1675 1248 1272 2392 8...
# 112            1006_A  1883 2353 2332 2450 1788 2197 305 2103 396 238...
# 486            1006_C  1883 2353 2332 2450 1788 2197 305 2103 396 117...
# ..                ...                                                ...
# 418             953_C  81 1058 1198 2016 1582 2252 2386 936 523 1293 ...
# 605             953_D  81 1198 1058 2016 1582 2386 2252 523 936 1240 ...
# 43              969_A  1471 2185 2119 2315 2165 1937 134 1231 621 201...
# 230             969_B  1471 2185 2119 2315 2165 134 1937 1231 2019 22...
# 417             969_C  1471 2119 2185 134 2315 2165 602 1031 621 1597...
#
# [561 rows x 2 columns]
